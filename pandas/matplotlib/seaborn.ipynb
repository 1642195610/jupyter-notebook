# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']

# %%
plt.rcParams['axes.unicode_minus'] = False

# %%
# i = sns.load_dataset('iris')

# %%
# i.to_csv('iris.csv')

# %%
iris = pd.read_csv('iris.csv',index_col=0)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# multivariate_normal 协方差矩阵
# 协方差:衡量两个变量之间的相似度
# 协方差越大,两个变量相互影响越大
d = np.random.multivariate_normal([0,0],[[5,2],[2,2]],size = 2000)
d = pd.DataFrame(i,columns =['x','y'])
for col in 'xy':
    plt.hist(d[col],bins = 50,alpha = 0.6)
# 2个变量之间的分布关系

# %%
help(plt)
# Out:
# Help on module matplotlib.pyplot in matplotlib:
#
# NAME
#     matplotlib.pyplot
#
# DESCRIPTION
#     `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
#     a MATLAB-like way of plotting.
#
#     pyplot is mainly intended for interactive plots and simple cases of
#     programmatic plot generation::
#
#         import numpy as np
#         import matplotlib.pyplot as plt
#
#         x = np.arange(0, 5, 0.1)
#         y = np.sin(x)
#         plt.plot(x, y)
#
#     The object-oriented API is recommended for more complex plots.
#
# FUNCTIONS
#     acorr(x, *, data=None, **kwargs)
#         Plot the autocorrelation of *x*.
#
#         Parameters
#         ----------
#         x : array-like
#
#         detrend : callable, optional, default: `mlab.detrend_none`
#             *x* is detrended by the *detrend* callable. This must be a
#             function ``x = detrend(x)`` accepting and returning an
#             `numpy.array`. Default is no normalization.
#
# ...

# %%
# 核密度图
for col in "xy":
    sns.kdeplot(d[col],shade = True)

# %%
c = np.random.randn(10000)
sns.kdeplot(c,shade = True)

# %%
sns.distplot(d['x'])
sns.distplot(d['y'])

# %%
sns.distplot(d['x'])

# %%
a = np.random.randn(10000)
a2 = np.random.rand(1000)
sns.distplot(a)
sns.distplot(a2)

# %%
d = np.random.multivariate_normal([0,0],[[5,2],[2,2]],size = 2000)
d = pd.DataFrame(i,columns =['x','y'])

# %%
d
# Out:
#              x         y
# 0     0.033759  0.820989
# 1    -0.247132  0.089710
# 2     0.670685  1.920154
# 3    -0.377319 -1.032843
# 4     0.047741 -1.518224
# ...        ...       ...
# 1995 -1.745764 -0.709761
# 1996  0.110546  0.981338
# 1997  0.800862 -0.046641
# 1998  1.496780  1.678288
# 1999 -0.701184 -1.157914
#
# [2000 rows x 2 columns]

# %%
# x和y的关系
import warnings
warnings.filterwarnings('ignore')
sns.kdeplot(d)

# %%
# jointplot 联合图
# 两个变量之间的联合分布
sns.jointplot('x','y',d,kind = 'kde')

# %%
sns.jointplot('x','y',d,kind = 'scatter')

# %%
sns.jointplot('x','y',d,kind = 'hex')

# %%
d = np.random.multivariate_normal([0,0],[[5,2],[2,2]],size = 200000)
d = pd.DataFrame(i,columns =['x','y'])
sns.jointplot('x','y',d,kind = 'kde')

# %%
sns.jointplot('x','y',d,kind = 'hex')

# %%
sns.jointplot('x','y',d,kind = 'reg') # regression

# %% [markdown]
# # 多变量图

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris['species'].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
# 对图 pairplot
# hue = 'species' 图里的数据类别,species里面有3个类别
sns.pairplot(iris,hue = 'species',height = 2.5)

# %%
sns.pairplot(iris,hue = 'species',height = 2.5,kind = 'reg')

# %%
sns.pairplot(iris,hue = 'species',height = 2.5,kind = 'kde')

# %%
sns.pairplot(iris,hue = 'species',height = 2.5,kind = 'line')

# %%
sns.pairplot(iris,hue = 'species',height = 2.5,kind = 'hist')

# %% [markdown]
# # 箱线图

# %%
# boxplot 箱线图
sns.boxplot(x = 'species',y ='sepal_length',data = iris)

# %%
sns.boxplot(x = 'sepal_width',y ='sepal_length',data = iris)

# %% [markdown]
# # 小提琴图

# %%
# violinplot 小提琴图
sns.violinplot(x = 'species',y ='sepal_length',data = iris)

# %%
sns.violinplot(x = 'sepal_width',y ='sepal_length',data = iris)

# %%
# violinplot 小提琴图 离散型数据
sns.violinplot(y = 'species',x ='sepal_length',data = iris)

# %%
sns.violinplot(y = 'sepal_width',x ='sepal_length',data = iris)

# %% [markdown]
# # 因子图

# %%
p = pd.read_csv('planets.csv',index_col = 0)
p.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
# p = sns.load_dataset('planets')
# p.head()

# %%
p.dtypes
# Out:
# Unnamed: 0          int64
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
# p.to_csv('planets.csv')

# %% [markdown]
# # 格子图

# %%
t = pd.read_csv('tips.csv',index_col = 0)
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# tips = sns.load_dataset('tips')
# tips.head()

# %%
t.dtypes
# Out:
# Unnamed: 0      int64
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
# tips.to_csv('tips.csv')

# %%
g = sns.FacetGrid(t,row = 'sex',col = 'time',margin_titles=True)
g.map(plt.hist,'total_bill',bins = np.linspace(0,70,15))

# %%
g = sns.FacetGrid(t,row = 'sex',col = 'time',margin_titles=True)
g.map(plt.hist,'tip',bins = np.linspace(0,70,15))

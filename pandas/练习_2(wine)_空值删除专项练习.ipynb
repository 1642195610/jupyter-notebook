# %% [markdown]
# # Wine(红酒数据集)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 读取数据

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
wine = pd.read_csv(url)
wine.head(5)
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
#读取数据

#显示数据前几行

# %% [markdown]
# ### Step 1. 删除第1,4,7,9,12,13,14列

# %%
wine.drop(wine.iloc[:,[0,3,6,8,11,12,13]],axis = 1,inplace = True)

# %%
wine.head(5)
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  5.64
# 0  13.20  1.78  11.2  100  2.76  1.28  4.38
# 1  13.16  2.36  18.6  101  3.24  2.81  5.68
# 2  14.37  1.95  16.8  113  3.49  2.18  7.80
# 3  13.24  2.59  21.0  118  2.69  1.82  4.32
# 4  14.20  1.76  15.2  112  3.39  1.97  6.75

# %%
# 删除列

#查看数据

# %% [markdown]
# ### Step 5. 列命名:
#
# 1) alcohol 酒精度
# 2) malic_acid 苹果酸
# 3) alcalinity_of_ash 碱度
# 4) magnesium  Mg含量
# 5) flavanoids  黄酮类化合物
# 6) proanthocyanins 花青素
# 7) hue 色度

# %%
wine.columns
# Out:
# Index(['14.23', '1.71', '15.6', '127', '3.06', '2.29', '5.64'], dtype='object')

# %%
columns = ['酒精度','苹果酸','碱度','Mg含量','黄酮类化合物','花青素','色度']
columns
# Out:
# ['酒精度', '苹果酸', '碱度', 'Mg含量', '黄酮类化合物', '花青素', '色度']

# %%
wine.columns = columns

# %%
wine.head(5)
# Out:
#      酒精度   苹果酸    碱度  Mg含量  黄酮类化合物   花青素    色度
# 0  13.20  1.78  11.2   100    2.76  1.28  4.38
# 1  13.16  2.36  18.6   101    3.24  2.81  5.68
# 2  14.37  1.95  16.8   113    3.49  2.18  7.80
# 3  13.24  2.59  21.0   118    2.69  1.82  4.32
# 4  14.20  1.76  15.2   112    3.39  1.97  6.75

# %%
# 添加列名,可用中文,也可以用英文

# %% [markdown]
# ### 把酒精度的前三行数据设为空值

# %%
import warnings
warnings.filterwarnings(action = "ignore")
wine['酒精度'][0:3] = np.nan
wine.head(5)
# Out:
#      酒精度   苹果酸    碱度  Mg含量  黄酮类化合物   花青素    色度
# 0    NaN  1.78  11.2   100    2.76  1.28  4.38
# 1    NaN  2.36  18.6   101    3.24  2.81  5.68
# 2    NaN  1.95  16.8   113    3.49  2.18  7.80
# 3  13.24  2.59  21.0   118    2.69  1.82  4.32
# 4  14.20  1.76  15.2   112    3.39  1.97  6.75

# %%
#索引或切片数据然后赋值

# 显示数据

# %% [markdown]
# ### 把镁离子含量列的第3,4两行值设为空值

# %%
wine['Mg含量'][2:4] = np.nan
wine.head(5)
# Out:
#      酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素    色度
# 0    NaN  1.78  11.2  100.0    2.76  1.28  4.38
# 1    NaN  2.36  18.6  101.0    3.24  2.81  5.68
# 2    NaN  1.95  16.8    NaN    3.49  2.18  7.80
# 3  13.24  2.59  21.0    NaN    2.69  1.82  4.32
# 4  14.20  1.76  15.2  112.0    3.39  1.97  6.75

# %%
#索引或切片数据然后赋值

#显示数据

# %% [markdown]
# ### Step 8.把酒精度列的空值填充为10,把镁离子浓度列的空值填充为100

# %%
wine.fillna({"酒精度":10,
             "Mg含量":100},
            inplace = False)
# Out:
#        酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素     色度
# 0    10.00  1.78  11.2  100.0    2.76  1.28   4.38
# 1    10.00  2.36  18.6  101.0    3.24  2.81   5.68
# 2    10.00  1.95  16.8  100.0    3.49  2.18   7.80
# 3    13.24  2.59  21.0  100.0    2.69  1.82   4.32
# 4    14.20  1.76  15.2  112.0    3.39  1.97   6.75
# ..     ...   ...   ...    ...     ...   ...    ...
# 172  13.71  5.65  20.5   95.0    0.61  1.06   7.70
# 173  13.40  3.91  23.0  102.0    0.75  1.41   7.30
# 174  13.27  4.28  20.0  120.0    0.69  1.35  10.20
# 175  13.17  2.59  20.0  120.0    0.68  1.46   9.30
# 176  14.13  4.10  24.5   96.0    0.76  1.35   9.20
#
# [177 rows x 7 columns]

# %%
wine.head(5)
# Out:
#      酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素    色度
# 0    NaN  1.78  11.2  100.0    2.76  1.28  4.38
# 1    NaN  2.36  18.6  101.0    3.24  2.81  5.68
# 2    NaN  1.95  16.8    NaN    3.49  2.18  7.80
# 3  13.24  2.59  21.0    NaN    2.69  1.82  4.32
# 4  14.20  1.76  15.2  112.0    3.39  1.97  6.75

# %%
# 填充酒精度

# 填充镁离子浓度

wine.head()
# Out:
#      酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素    色度
# 0    NaN  1.78  11.2  100.0    2.76  1.28  4.38
# 1    NaN  2.36  18.6  101.0    3.24  2.81  5.68
# 2    NaN  1.95  16.8    NaN    3.49  2.18  7.80
# 3  13.24  2.59  21.0    NaN    2.69  1.82  4.32
# 4  14.20  1.76  15.2  112.0    3.39  1.97  6.75

# %% [markdown]
# ### Step 9. 查看空值数量

# %%
pd.isnull(wine).sum()
# Out:
# 酒精度       3
# 苹果酸       0
# 碱度        0
# Mg含量      2
# 黄酮类化合物    0
# 花青素       0
# 色度        0
# dtype: int64

# %%
#isnull

# %%
random = np.random.randint(10, size = 10)
random
# Out:
# array([7, 8, 9, 8, 7, 8, 9, 8, 7, 8])

# %% [markdown]
# ### Step 11.  构造一个随机整数数组(范围为0-10),把酒精度对应的行设为空值

# %%
r = np.random.randint(0,11,10)

# %%
r
# Out:
# array([4, 3, 8, 3, 5, 6, 0, 1, 4, 9])

# %%
wine['酒精度'][r] = np.nan

# %%
pd.isnull(wine).sum()
# Out:
# 酒精度       9
# 苹果酸       0
# 碱度        0
# Mg含量      2
# 黄酮类化合物    0
# 花青素       0
# 色度        0
# dtype: int64

# %%
#生成一个整数随机数组,范围0-10

#把随机数作为索引更改酒精对应的数据为空值

#查看空值数量

#查看数据

# %% [markdown]
# ### 删除含有空值的行

# %%
wine.dropna(how = 'any',inplace = True)

# %%
wine['酒精度'] != np.nan
# Out:
# 7      True
# 10     True
# 11     True
# 12     True
# 13     True
#        ...
# 172    True
# 173    True
# 174    True
# 175    True
# 176    True
# Name: 酒精度, Length: 168, dtype: bool

# %%
pd.isnull(wine.sum())
# Out:
# 酒精度       False
# 苹果酸       False
# 碱度        False
# Mg含量      False
# 黄酮类化合物    False
# 花青素       False
# 色度        False
# dtype: bool

# %%
# dropna删除操作

# 查看数据
wine.head()
# Out:
#       酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素   色度
# 7   14.83  1.64  14.0   97.0    2.98  1.98  5.2
# 10  14.12  1.48  16.8   95.0    2.43  1.57  5.0
# 11  13.75  1.73  16.0   89.0    2.76  1.81  5.6
# 12  14.75  1.73  11.4   91.0    3.69  2.81  5.4
# 13  14.38  1.87  12.0  102.0    3.64  2.96  7.5

# %%
wine.酒精度 != np.nan
# Out:
# 7      True
# 10     True
# 11     True
# 12     True
# 13     True
#        ...
# 172    True
# 173    True
# 174    True
# 175    True
# 176    True
# Name: 酒精度, Length: 168, dtype: bool

# %% [markdown]
# ### 找到酒精度非空数据

# %%
wine[wine['酒精度'] != np.nan]
# Out:
#        酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素    色度
# 7    14.83  1.64  14.0   97.0    2.98  1.98   5.2
# 10   14.12  1.48  16.8   95.0    2.43  1.57   5.0
# 11   13.75  1.73  16.0   89.0    2.76  1.81   5.6
# 12   14.75  1.73  11.4   91.0    3.69  2.81   5.4
# 13   14.38  1.87  12.0  102.0    3.64  2.96   7.5
# ..     ...   ...   ...    ...     ...   ...   ...
# 172  13.71  5.65  20.5   95.0    0.61  1.06   7.7
# 173  13.40  3.91  23.0  102.0    0.75  1.41   7.3
# 174  13.27  4.28  20.0  120.0    0.69  1.35  10.2
# 175  13.17  2.59  20.0  120.0    0.68  1.46   9.3
# 176  14.13  4.10  24.5   96.0    0.76  1.35   9.2
#
# [168 rows x 7 columns]

# %%
wine[wine.notnull()]
# Out:
#        酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素    色度
# 7    14.83  1.64  14.0   97.0    2.98  1.98   5.2
# 10   14.12  1.48  16.8   95.0    2.43  1.57   5.0
# 11   13.75  1.73  16.0   89.0    2.76  1.81   5.6
# 12   14.75  1.73  11.4   91.0    3.69  2.81   5.4
# 13   14.38  1.87  12.0  102.0    3.64  2.96   7.5
# ..     ...   ...   ...    ...     ...   ...   ...
# 172  13.71  5.65  20.5   95.0    0.61  1.06   7.7
# 173  13.40  3.91  23.0  102.0    0.75  1.41   7.3
# 174  13.27  4.28  20.0  120.0    0.69  1.35  10.2
# 175  13.17  2.59  20.0  120.0    0.68  1.46   9.3
# 176  14.13  4.10  24.5   96.0    0.76  1.35   9.2
#
# [168 rows x 7 columns]

# %%
# bool索引找到酒精度为非空的数据
# 方法一,用!=np.nan判断

#方法二,用notnull()方法判断

# %%
wine
# Out:
#        酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素    色度
# 7    14.83  1.64  14.0   97.0    2.98  1.98   5.2
# 10   14.12  1.48  16.8   95.0    2.43  1.57   5.0
# 11   13.75  1.73  16.0   89.0    2.76  1.81   5.6
# 12   14.75  1.73  11.4   91.0    3.69  2.81   5.4
# 13   14.38  1.87  12.0  102.0    3.64  2.96   7.5
# ..     ...   ...   ...    ...     ...   ...   ...
# 172  13.71  5.65  20.5   95.0    0.61  1.06   7.7
# 173  13.40  3.91  23.0  102.0    0.75  1.41   7.3
# 174  13.27  4.28  20.0  120.0    0.69  1.35  10.2
# 175  13.17  2.59  20.0  120.0    0.68  1.46   9.3
# 176  14.13  4.10  24.5   96.0    0.76  1.35   9.2
#
# [168 rows x 7 columns]

# %%
wine.reset_index()
# Out:
#      index    酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素    色度
# 0        7  14.83  1.64  14.0   97.0    2.98  1.98   5.2
# 1       10  14.12  1.48  16.8   95.0    2.43  1.57   5.0
# 2       11  13.75  1.73  16.0   89.0    2.76  1.81   5.6
# 3       12  14.75  1.73  11.4   91.0    3.69  2.81   5.4
# 4       13  14.38  1.87  12.0  102.0    3.64  2.96   7.5
# ..     ...    ...   ...   ...    ...     ...   ...   ...
# 163    172  13.71  5.65  20.5   95.0    0.61  1.06   7.7
# 164    173  13.40  3.91  23.0  102.0    0.75  1.41   7.3
# 165    174  13.27  4.28  20.0  120.0    0.69  1.35  10.2
# 166    175  13.17  2.59  20.0  120.0    0.68  1.46   9.3
# 167    176  14.13  4.10  24.5   96.0    0.76  1.35   9.2
#
# [168 rows x 8 columns]

# %%
wine
# Out:
#        酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素    色度
# 7    14.83  1.64  14.0   97.0    2.98  1.98   5.2
# 10   14.12  1.48  16.8   95.0    2.43  1.57   5.0
# 11   13.75  1.73  16.0   89.0    2.76  1.81   5.6
# 12   14.75  1.73  11.4   91.0    3.69  2.81   5.4
# 13   14.38  1.87  12.0  102.0    3.64  2.96   7.5
# ..     ...   ...   ...    ...     ...   ...   ...
# 172  13.71  5.65  20.5   95.0    0.61  1.06   7.7
# 173  13.40  3.91  23.0  102.0    0.75  1.41   7.3
# 174  13.27  4.28  20.0  120.0    0.69  1.35  10.2
# 175  13.17  2.59  20.0  120.0    0.68  1.46   9.3
# 176  14.13  4.10  24.5   96.0    0.76  1.35   9.2
#
# [168 rows x 7 columns]

# %% [markdown]
# ### 重设索引

# %%
wine.index = np.arange(wine.shape[0])

# %%
wine
# Out:
#        酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素     色度
# 0    14.39  1.87  14.6   96.0    2.52  1.98   5.25
# 1    14.06  2.15  17.6  121.0    2.51  1.25   5.05
# 2    13.75  1.73  16.0   89.0    2.76  1.81   5.60
# 3    14.75  1.73  11.4   91.0    3.69  2.81   5.40
# 4    14.38  1.87  12.0  102.0    3.64  2.96   7.50
# ..     ...   ...   ...    ...     ...   ...    ...
# 163  13.71  5.65  20.5   95.0    0.61  1.06   7.70
# 164  13.40  3.91  23.0  102.0    0.75  1.41   7.30
# 165  13.27  4.28  20.0  120.0    0.69  1.35  10.20
# 166  13.17  2.59  20.0  120.0    0.68  1.46   9.30
# 167  14.13  4.10  24.5   96.0    0.76  1.35   9.20
#
# [168 rows x 7 columns]

# %%
# reset_index()
# Out:
#        酒精度   苹果酸    碱度   Mg含量  黄酮类化合物   花青素         色度
# 0      NaN  1.78  11.2  100.0    2.76  1.28   4.380000
# 1      NaN  2.36  18.6  101.0    3.24  2.81   5.680000
# 2      NaN  1.95  16.8    NaN    3.49  2.18   7.800000
# 3      NaN  2.59  21.0    NaN    2.69  1.82   4.320000
# 4    14.20  1.76  15.2  112.0    3.39  1.97   6.750000
# 5      NaN  1.87  14.6   96.0    2.52  1.98   5.250000
# 6      NaN  2.15  17.6  121.0    2.51  1.25   5.050000
# 7      NaN  1.64  14.0   97.0    2.98  1.98   5.200000
# 8      NaN  1.35  16.0   98.0    3.15  1.85   7.220000
# 9    14.10  2.16  18.0  105.0    3.32  2.38   5.750000
# 10   14.12  1.48  16.8   95.0    2.43  1.57   5.000000
# 11   13.75  1.73  16.0   89.0    2.76  1.81   5.600000
# 12   14.75  1.73  11.4   91.0    3.69  2.81   5.400000
# 13   14.38  1.87  12.0  102.0    3.64  2.96   7.500000
# 14   13.63  1.81  17.2  112.0    2.91  1.46   7.300000
# 15   14.30  1.92  20.0  120.0    3.14  1.97   6.200000
# ...
